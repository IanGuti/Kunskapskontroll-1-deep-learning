# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: Ian Gutierrez
#
# Vem du har presenterat för: William Blennow och Filip Östlund
#
# Datum då du presenterade: 08-05-24
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
from PIL import Image

# %%
model = ResNet50(weights='imagenet')

# %%
# img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
img_path = 'tennisboll.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n03868863', 'oxygen_mask', 0.06329921), ('n03706229', 'magnetic_compass', 0.05651336), ('n04252077', 'snowmobile', 0.05395403)]

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %%
img_mouse = "mouse.jpg"
img_mouse = image.load_img(img_mouse, target_size=(224, 224))
img_mouse
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img_mouse)
x.shape
x = np.expand_dims(x, axis=0)
x.shape
x = preprocess_input(x)

preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 41ms/step
# Predicted: [('n03793489', 'mouse', 0.992141), ('n03777754', 'modem', 0.0066428273), ('n02860847', 'bobsled', 0.0003260643)]

# %%
img_cat = "cat.jpg"
img_cat = image.load_img(img_cat, target_size=(224, 224))
img_cat
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
rotated_cat = img_cat.transpose(Image.ROTATE_270)
rotated_cat
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(rotated_cat)
x.shape
x = np.expand_dims(x, axis=0)
x.shape
x = preprocess_input(x)

preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# Predicted: [('n02124075', 'Egyptian_cat', 0.113190286), ('n02123394', 'Persian_cat', 0.11162055), ('n02123045', 'tabby', 0.10055603)]

# %%
img_chess = "chess.jpg"
img_chess = image.load_img(img_chess, target_size=(224, 224))
img_chess
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
rotated_chess = img_chess.transpose(Image.ROTATE_270)
rotated_chess
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(rotated_chess)
x.shape
x = np.expand_dims(x, axis=0)
x.shape
x = preprocess_input(x)

preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 44ms/step
# Predicted: [('n04200800', 'shoe_shop', 0.33606553), ('n03840681', 'ocarina', 0.08026041), ('n04120489', 'running_shoe', 0.075980045)]

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %% [markdown]
# ## Because you can create a model and then save it to use it on for example a website which saves a lot of time since you don't need to train the model every time you use it.
